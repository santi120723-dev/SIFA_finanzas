# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

print("Proyecto:", project_root)
# Out:
# Proyecto: c:\Users\santi\SIFA_finanzas

# %%
from src.config import LIBRO_MAYOR

from src.ingestion.extract import load_file
from src.utils.cleaning import clean_dataframe

df = load_file(
    LIBRO_MAYOR,
    file_type="libro_mayor"
)

df = clean_dataframe(
    df,
    file_type="libro_mayor"
)

print(df.columns.tolist())
# Out:
# 2026-06-05 21:42:46,180 | INFO     | etl_pipeline | Archivo cargado: libro_mayor_2025.xlsx | Filas: 252752 | Columnas: 7
# 2026-06-05 21:42:46,183 | INFO     | etl_pipeline | Iniciando limpieza genérica para dataset: libro_mayor
# 2026-06-05 21:42:46,184 | INFO     | etl_pipeline | Normalizando nombres de columnas...
# 2026-06-05 21:42:46,187 | INFO     | etl_pipeline | Nombres de columnas normalizados.
# 2026-06-05 21:42:46,188 | INFO     | etl_pipeline | Limpiando columnas de tipo string...
# 2026-06-05 21:42:46,792 | INFO     | etl_pipeline | Columnas de tipo string limpiadas.
# 2026-06-05 21:42:46,794 | INFO     | etl_pipeline | Estandarizando valores nulos...
# 2026-06-05 21:42:47,674 | INFO     | etl_pipeline | Valores nulos estandarizados.
# 2026-06-05 21:42:47,681 | INFO     | etl_pipeline | Limpieza genérica completada. Filas: 252752, Columnas: 7
# ['unnamed_0', 'unnamed_1', '2025', 'unnamed_3', 'unnamed_4', 'unnamed_5', 'unnamed_6']

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.config import LIBRO_MAYOR
import pandas as pd

df_raw = pd.read_excel(
    LIBRO_MAYOR,
    header=None
)

for i in range(8):
    print(f"\n===== FILA {i} =====")
    print(df_raw.iloc[i].tolist())
# Out:
# ===== FILA 0 =====
# [nan, nan, '2025', nan, nan, nan, nan]
#
# ===== FILA 1 =====
# [nan, nan, nan, nan, nan, nan, nan]
#
# ===== FILA 2 =====
# ['Código', 'Nombre de la cuenta', 'Fecha de factura', 'Contacto', 'Debe  ', 'Haber ', 'Valor Final']
#
# ===== FILA 3 =====
# [110505, 'Efectivo', nan, nan, 26082540, 26082540, 0]
#
# ===== FILA 4 =====
# [nan, 'MISC/2025/03/0403 PAGO FE 52', '28/03/2025', 'GRUPO MAREMI COLOMBIA S.A.S', 0, 56250, -56250]
#
# ===== FILA 5 =====
# [nan, 'COBAN10 (MARZO AHORROS 5126) CRUCE FACTURA ', '31/03/2025', 'GRUPO MAREMI COLOMBIA S.A.S', 56250, 0, 0]
#
# ===== FILA 6 =====
# [nan, 'COBAN7 (MARZO BBVA) CRUCE SALDO A FAVOR', '31/03/2025', 'ANDICOLOR S.A.', 26290, 0, 26290]
#
# ===== FILA 7 =====
# [nan, 'MISC/2025/03/0426 PAGO ANDICOLOR', '31/03/2025', 'ANDICOLOR S.A.', 0, 26290, 0]
